# %% [markdown]
# <a href="https://colab.research.google.com/github/ShoryaDubey/ML/blob/main/Decision_tree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("arpikr/petrol-consumption")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/petrol-consumption

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/kaggle/input/petrol-consumption/petrol_consumption.csv')

# %%
print(df.iloc[:2])
# Out:
#    Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)  \
# 0         9.0            3571            1976                         0.525
# 1         9.0            4092            1250                         0.572
#
#    Petrol_Consumption
# 0                 541
# 1                 524

# %%
X = df.iloc[:, :-1].values
Y = df.iloc[:, -1].values

# %%
x_train, x_test, y_train, y_test = train_test_split(
    X, Y, test_size=0.3, random_state=42
)

# %%
print(y_train)
# Out:
# [508 714 510 635 498 603 534 577 610 541 554 571 457 471 487 524 782 540
#  561 640 644 547 699 580 464 865 524 649 467 632 566 574 648]

# %%
dt = DecisionTreeRegressor(random_state=0,min_samples_split=5, max_depth=20)
dt.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=20, min_samples_split=5, random_state=0)

# %%
from sklearn.metrics import r2_score, mean_squared_error

# model score (R^2)
print("Train Score:", dt.score(x_train, y_train))
print("Test Score :", dt.score(x_test, y_test))

# additional metrics
y_pred = dt.predict(x_test)
print("R2 Score:", r2_score(y_test, y_pred))
print("MSE:", mean_squared_error(y_test, y_pred))
print("RMSE:", mean_squared_error(y_test, y_pred))
# Out:
# Train Score: 0.9302338824438717
# Test Score : 0.6100578279835993
# R2 Score: 0.6100578279835993
# MSE: 8199.208333333334
# RMSE: 8199.208333333334
